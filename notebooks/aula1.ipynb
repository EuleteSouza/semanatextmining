# %% [markdown]
# # Inteligência Artificial (guarda-chuva)
# - Imitação do humano
# - Ajudar o ser humano na produtividade
# - Imitar a inteligência humana e seus sentidos
# Reconhecer padrões e resolver problemas

# %% [markdown]
# # Machine Learning
# - Supervisionado: dados rotulados
# - Não supervisionado: sem dados rotulados

# %% [markdown]
# # Deep Learning
# - A diferença ele possui redes neurais

# %% [markdown]
# # O que você pode fazer:
# ### 1 - Transformar texto em áudio (falar).
# ### 2 - Identificar e comparar imagens e objetos (ver).
# ### 3 - Aplicar a física (raio cósmico): modelos quer encapsulam funções - velocidade de processamento e entendimento da função.
# ### 4 - Engenharia Civil encapsula funções.
# ### 5 - Mídias sociais - estão te ouvindo para oferecer um produto.
# ### 6- Policia
#   - viés: restrições (preconceituosa)
#   - variância: flexibilidade
#   - underfitting
#   - overfitting
# ### 7 - Jogos
#
# - Por reforço
# - Xadrez

# %% [markdown]
# # O que você pode fazer com a IA:

# %% [markdown]
# - Inferir espécie de uma flor a partir das medidas desta;
# - DataSet: íris (código genético e fenótipos)
# - Transformar um dígito escrito a mão em texto (string)
# - Recomenda filmes - base dataset de avaliações
# - Analise de sentimentos
# - Detectar objetos
# - Treinar um taxi autônomo

# %% [markdown]
# # Métricas

# %% [markdown]
# - Métrica é uma régua para medir o desempenho dos nossos modelo.
# - Função de custo e otimizadores (discerne se a predição é boa ou ruim) - erro quadrático médio

# %% [markdown]
# # Terminologias

# %% [markdown]
# - Ciência de Dados: campo acadêmico interdisciplinar para sugestões de insights e tomada de decisão

# %% [markdown]
# - Overffiting: aprendeu demais

# %% [markdown]
# underfitting: não aprendeu

# %% [markdown]
# - Viés: restrições impostas na função

# %% [markdown]
# - Variância: flexibilidade da técnica em se adaptar os dados.

# %% [markdown]
# # DataSet: Íris

# %%
url = 'https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv'

# %%
! pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\ead\desktop\semanatextmining_tarde\.venv\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\ead\desktop\semanatextmining_tarde\.venv\lib\site-packages (from pandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ead\desktop\semanatextmining_tarde\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ead\desktop\semanatextmining_tarde\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ead\desktop\semanatextmining_tarde\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\ead\desktop\semanatextmining_tarde\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd

# %% [markdown]
# # DataSet prático: Íris
# - inferir referente aos gêneros das flores
# - Medida de pétalas e sépalas(amostras)
# - Exercício:

# %%
df = pd.read_csv(url)

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Inferir espécie de uma flor a partir das medidas desta;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # List Comprehension

# %%
df.columns = [s.replace('.','_')for s in df.columns]

# %%
df.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa

# %%
df['variety'].value_counts()
# Out:
# variety
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: count, dtype: int64

# %% [markdown]
# ### estão bem distribuidas
# ### E as medidas?

# %%
df_setosa = df.query('variety == "Setosa"').copy()
df_versicolor = df.query('variety == "Versicolor"').copy()
df_virginica = df.query('variety == "Virginica"').copy()

# %%
medidas = ['sepal_length','sepal_width','petal_lenght','petal_width']

# %%
! pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\ead\desktop\semanatextmining_tarde\.venv\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ead\desktop\semanatextmining_tarde\.venv\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ead\desktop\semanatextmining_tarde\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ead\desktop\semanatextmining_tarde\.venv\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ead\desktop\semanatextmining_tarde\.venv\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\ead\desktop\semanatextmining_tarde\.venv\lib\site-packages (from matplotlib) (2.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\ead\desktop\semanatextmining_tarde\.venv\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\ead\desktop\semanatextmining_tarde\.venv\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ead\desktop\semanatextmining_tarde\.venv\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ead\desktop\semanatextmining_tarde\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ead\desktop\semanatextmining_tarde\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
print('Setosa')
df_setosa[medidas].hist()
# Out:
# Setosa
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 2
#       1 print('Setosa')
# ----> 2 df_setosa[medidas].hist()
#
# File c:\Users\ead\Desktop\semanatextmining_tarde\.venv\lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\ead\Desktop\semanatextmining_tarde\.venv\lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\Users\ead\Desktop\semanatextmining_tarde\.venv\lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['petal_lenght'] not in index"

# %%
print('Setosa')
df_setosa[medidas].hist()
# Out:
# Setosa
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 2
#       1 print('Setosa')
# ----> 2 df_setosa[medidas].hist()
#
# File c:\Users\ead\Desktop\semanatextmining_tarde\.venv\lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\ead\Desktop\semanatextmining_tarde\.venv\lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\Users\ead\Desktop\semanatextmining_tarde\.venv\lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['petal_lenght'] not in index"

# %%
print('Virginica')
df_virginica[medidas].hist()
# Out:
# Virginica
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 2
#       1 print('Virginica')
# ----> 2 df_virginica[medidas].hist()
#
# File c:\Users\ead\Desktop\semanatextmining_tarde\.venv\lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\ead\Desktop\semanatextmining_tarde\.venv\lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\Users\ead\Desktop\semanatextmining_tarde\.venv\lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['petal_lenght'] not in index"

# %% [markdown]
# # Filtro de valor específico de medida

# %%
df.query('petal_length > 5')['variety'].value_counts()
# Out:
# variety
# Virginica     41
# Versicolor     1
# Name: count, dtype: int64

# %% [markdown]
#  Conclusão: praticamente só as plantas da espécie Virgínica têm comprimento de pétala maior q 5!
#
#  Nenhuma amostra da setosa possui essa medida maior que 5.
#
#  - Isso nos diz que a variável "petal_length" possui um bom poder preditivo referente a "variety".
#  - Quais amostras são de uma espécie e quais não são.

# %% [markdown]
# # A inteligência artificial possui as seguintes categorias e aplicações:
#
# - Aprendizado por Reforço: jogos (tentativa e erro (ambiente))

# %% [markdown]
# - Agente: um jogador
# - Ambiente: problema a ser resolvido
# - Ação: é a saída do modelo.

# %% [markdown]
# - Aprendizado Supervisionado e Não Supervisionado

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png) ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
